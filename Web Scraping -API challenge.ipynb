# %% [markdown]
# Challenge
# Do a little scraping or API-calling of your own. Pick a new website and see what you can get out of it. Expect that you'll run into bugs and blind alleys, and rely on your mentor to help you get through.
#
# Formally, your goal is to write a scraper that will:
#
# 1) Return specific pieces of information (rather than just downloading a whole page)<br/>
# 2) Iterate over multiple pages/queries<br/>
# 3) Save the data to your computer<br/>
#
# Once you have your data, compute some statistical summaries and/or visualizations that give you some new insights into your scraping topic of interest. Write up a report from scraping code to summary and share it with your mentor.

# %% [markdown]
# # Web Scraper - recursive

# %%
#pip install scrapy

# %%
import scrapy
import re
from scrapy.crawler import CrawlerProcess

class ESSpider(scrapy.Spider):
    name = "spider_4"
    
    start_urls = [
        'http://quotes.toscrape.com/',
    ]

    # Use XPath to parse the response we get.
    def parse(self, response):
        
        # Iterate over every <article> element on the page.
        for article in response.xpath('//div'):
            
            # Yield a dictionary with the values we want.
            yield {
                'body': div.xpath('span[@class="text"]/text()').extract_first(),
                'author': div.xpath('span[@class="author"]/a/text()').extract(),
                'tags': div.xpath('*/div[@class="tag"]/a/text()').extract()
            }

# Tell the script how to run the crawler by passing in settings.
process = CrawlerProcess({
    'FEED_FORMAT': 'json',         # Store data in JSON format.
    'FEED_URI': 'bla.json',        # Name our storage file.
    'LOG_ENABLED': False           # Turn off logging for now.
})

# Start the crawler with our spider.
process.crawl(ESSpider)
process.start()
print('Success!')
# Out:
# Success!

# %%
import pandas as pd
#pandas.read_json(open("ut1.json", "r", encoding="utf8"))

firstpage = pd.read_json('bla.json', lines=True ,orient='records')
print(firstpage.shape)
print(firstpage.head())
# Out:
# (0, 0)
# Empty DataFrame
# Columns: []
# Index: []
