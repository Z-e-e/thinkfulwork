# %% [markdown]
# # Importing Data

# %% [markdown]
# This package is important in order to be able to use pandas_datareader.

# %%
pip install pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# pandas_datareader is used to access data from web sources

# %%
import pandas_datareader as pdr
import datetime 
aapl = pdr.get_data_yahoo('AAPL', 
                          start=datetime.datetime(2006, 10, 1), 
                          end=datetime.datetime(2012, 1, 1))

# %%
pip install quandl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import quandl 
aapl = quandl.get("WIKI/AAPL", start_date="2006-10-01", end_date="2012-01-01")

# %%
quandl.ApiConfig.api_key = 'ZwzwyH3HehyBQ39eDe7A'
x=quandl.get('GDAX/BTC_USD', start_date='2009-01-01', end_date='2019-07-15')
x.head()
# Out:
#                Open     High      Low       Volume
# Date
# 2018-07-06  6538.34  6639.00  6452.20  5183.065904
# 2018-07-07  6573.07  6614.80  6512.00  3099.314068
# 2018-07-08  6569.10  6843.26  6568.96  4428.180442
# 2018-07-09  6740.04  6815.82  6660.01  5090.870286
# 2018-07-10  6700.80  6700.80  6320.16  7928.435317

# %%
quandl.ApiConfig.api_key = 'ZwzwyH3HehyBQ39eDe7A'
dl=quandl.get('GDAX/BTC_USD')
dl.head()
# Out:
#                Open     High      Low       Volume
# Date
# 2018-07-06  6538.34  6639.00  6452.20  5183.065904
# 2018-07-07  6573.07  6614.80  6512.00  3099.314068
# 2018-07-08  6569.10  6843.26  6568.96  4428.180442
# 2018-07-09  6740.04  6815.82  6660.01  5090.870286
# 2018-07-10  6700.80  6700.80  6320.16  7928.435317

# %%
quandl.ApiConfig.api_key = 'ZwzwyH3HehyBQ39eDe7A'
quandl.get('BATS/EDGA_XLTY')
# Out:
#             Short Volume  Total Volume
# Date
# 2018-12-14          99.0          99.0
# 2019-01-03         100.0         100.0
# 2019-01-04         100.0         100.0
# 2019-02-08          80.0          80.0
# 2019-05-31         386.0         386.0

# %%
quandl.ApiConfig.api_key = 'ZwzwyH3HehyBQ39eDe7A'
df=quandl.get('LOCALBTC/XRP', start_date='2018-02-01', end_date='2019-07-15')
df.head()
# Out:
#             24h Average  12h Average      Last  Volume (BTC)
# Date
# 2018-02-16      9262.46      9262.46   9262.46      0.016194
# 2018-03-01     12394.88          NaN  12412.80      0.003772
# 2018-03-02     10678.22     12778.39  12778.39      0.081765
# 2018-03-03     13238.99     13345.06  13345.06      0.004759
# 2018-03-04     13034.80     13034.80  13034.80      0.003337

# %%
df.tail()
# Out:
#             24h Average  12h Average      Last  Volume (BTC)
# Date
# 2019-07-11     35646.37     35686.15  37020.83      0.300569
# 2019-07-12     35625.63     34309.01  35259.74      0.190147
# 2019-07-13     34637.35     34584.48  32941.98      0.112494
# 2019-07-14     33778.83     33753.01  34338.19      0.059109
# 2019-07-15     33843.46     34058.07  35467.17      0.186196

# %%
from pandas_datareader import wb
mathces = wb.search('gdp.*capita.*const')
mathces.head()
# Out:
#                         id                                               name  \
# 646     6.0.GDPpc_constant  GDP per capita, PPP (constant 2011 internation...
# 8877        NY.GDP.PCAP.KD                 GDP per capita (constant 2010 US$)
# 8879        NY.GDP.PCAP.KN                      GDP per capita (constant LCU)
# 8881     NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2011 internation...
# 8882  NY.GDP.PCAP.PP.KD.87  GDP per capita, PPP (constant 1987 internation...
#
#                             source  \
# 646                 LAC Equity Lab
# 8877  World Development Indicators
# 8879  World Development Indicators
# 8881  World Development Indicators
# 8882         WDI Database Archives
#
#                                              sourceNote  \
# 646   GDP per capita based on purchasing power parit...
# 8877  GDP per capita is gross domestic product divid...
# 8879  GDP per capita is gross domestic product divid...
# ...

# %%
quandl.ApiConfig.api_key = 'ZwzwyH3HehyBQ39eDe7A'
gold=quandl.get('NASDAQOMX/XQC')
gold.head()
# Out:
#             Index Value  High  Low  Total Market Value  Dividend Market Value
# Trade Date
# 2016-12-19      4934.85   0.0  0.0                 0.0                    0.0
# 2016-12-20      4953.80   0.0  0.0                 0.0                    0.0
# 2016-12-21      4948.90   0.0  0.0                 0.0                    0.0
# 2016-12-22      4934.39   0.0  0.0                 0.0                    0.0
# 2016-12-23      4940.02   0.0  0.0                 0.0                    0.0

# %%
gold.tail()
# Out:
#             Index Value  High  Low  Total Market Value  Dividend Market Value
# Trade Date
# 2019-07-10      7903.40   0.0  0.0                 0.0                    0.0
# 2019-07-11      7896.78   0.0  0.0                 0.0                    0.0
# 2019-07-12      7943.24   0.0  0.0                 0.0                    0.0
# 2019-07-15      7966.93   0.0  0.0                 0.0                    0.0
# 2019-07-16         0.00   0.0  0.0                 0.0                    0.0

# %%
quandl.ApiConfig.api_key = 'ZwzwyH3HehyBQ39eDe7A'
y=quandl.get('CHRIS/MGEX_IH1')
y.head()
# Out:
#               Open    High     Low    Last  Volume  Open Interest
# Date
# 2005-01-03  321.00  321.00  321.00  321.00     0.0            0.0
# 2005-01-04  318.00  318.00  318.00  318.00     0.0            0.0
# 2005-01-05  319.25  319.25  319.25  319.25     0.0            0.0
# 2005-01-06  328.00  328.00  328.00  328.00     0.0            0.0
# 2005-01-07  328.00  329.50  328.00  329.50     0.0            0.0

# %%
y.tail()
# Out:
#             Open   High    Low   Last  Volume  Open Interest
# Date
# 2019-07-09   NaN  429.0  429.0  429.0     0.0            0.0
# 2019-07-10   NaN  429.0  429.0  429.0     0.0            0.0
# 2019-07-11   NaN  430.0  430.0  430.0     0.0            0.0
# 2019-07-12   NaN  443.0  443.0  443.0     0.0            0.0
# 2019-07-15   NaN  438.0  438.0  438.0     0.0            0.0

# %%
quandl.ApiConfig.api_key = 'ZwzwyH3HehyBQ39eDe7A'
gold1=quandl.get('LBMA/GOLD')
gold1.head()
# Out:
#             USD (AM)  USD (PM)  GBP (AM)  GBP (PM)  EURO (AM)  EURO (PM)
# Date
# 1968-01-02     35.18       NaN    14.641       NaN        NaN        NaN
# 1968-01-03     35.16       NaN    14.617       NaN        NaN        NaN
# 1968-01-04     35.14       NaN    14.603       NaN        NaN        NaN
# 1968-01-05     35.14       NaN    14.597       NaN        NaN        NaN
# 1968-01-08     35.14       NaN    14.586       NaN        NaN        NaN

# %%
import pandas_datareader.data as web
f = web.DataReader('F', 'robinhood')
f.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-bd5d30254441> in <module>
#       1 import pandas_datareader.data as web
# ----> 2 f = web.DataReader('F', 'robinhood')
#       3 f.head()
#
# ~\Anaconda3\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     389         return RobinhoodHistoricalReader(symbols=name, start=start, end=end,
#     390                                          retry_count=retry_count, pause=pause,
# --> 391                                          session=session).read()
#     392     elif data_source == 'tiingo':
#     393         return TiingoDailyReader(symbols=name, start=start, end=end,
#
# ~\Anaconda3\lib\site-packages\pandas_datareader\base.py in read(self)
#      75         """Read data from connector"""
#      76         try:
# ...

# %%
dat = wb.download(indicator='NY.GDP.PCAP.KD', country=['US', 'CA', 'MX'], start=2000, end=2018)
print(dat)
# Out:
#                     NY.GDP.PCAP.KD
# country       year
# Canada        2018    51357.753975
#               2017    51126.184351
#               2016    50236.535070
#               2015    50255.572447
#               2014    50292.924778
#               2013    49389.057155
#               2012    48781.979704
#               2011    48464.534172
#               2010    47450.318470
#               2009    46546.021668
#               2008    48511.327795
#               2007    48553.466102
#               2006    48036.571090
#               2005    47283.840663
#               2004    46251.920056
#               2003    45287.808431
#               2002    44889.061770
#               2001    44053.851901
#               2000    43759.930266
# Mexico        2018    10385.297846
#               2017    10297.586208
#               2016    10206.893454
#               2015    10037.201490
#               2014     9839.050191
#               2013     9693.722969
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(dat)
plt.show()

# %%
import quandl 
aapl = quandl.get("WIKI/AAPL", start_date="2017-01-01", end_date="2018-01-01")
aapl.head()
# Out:
#               Open      High     Low   Close      Volume  Ex-Dividend  \
# Date
# 2017-01-03  115.80  116.3300  114.76  116.15  28781865.0          0.0
# 2017-01-04  115.85  116.5100  115.75  116.02  21118116.0          0.0
# 2017-01-05  115.92  116.8642  115.81  116.61  22193587.0          0.0
# 2017-01-06  116.78  118.1600  116.47  117.91  31751900.0          0.0
# 2017-01-09  117.95  119.4300  117.94  118.99  33561948.0          0.0
#
#             Split Ratio   Adj. Open   Adj. High    Adj. Low  Adj. Close  \
# Date
# 2017-01-03          1.0  114.369701  114.893155  113.342546  114.715378
# 2017-01-04          1.0  114.419083  115.070931  114.320318  114.586983
# 2017-01-05          1.0  114.488219  115.420756  114.379577  115.169696
# 2017-01-06          1.0  115.337596  116.700551  115.031425  116.453639
# 2017-01-09          1.0  116.493145  117.954865  116.483269  117.520300
#
#             Adj. Volume
# Date
# 2017-01-03   28781865.0
# 2017-01-04   21118116.0
# ...

# %%
# Import Matplotlib's `pyplot` module as `plt`
import matplotlib.pyplot as plt

# Plot the closing prices for `aapl`
aapl['Close'].plot(grid=True)

# Show the plot
plt.show()
